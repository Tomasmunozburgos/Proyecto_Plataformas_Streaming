# %% [markdown]
#                                                         E   D   A

# %% [markdown]
# Recopilación de datos: El primer paso es recopilar los datos que se analizarán. Los datos pueden provenir de diversas fuentes, como bases de datos, archivos CSV o Excel, o webscrapping, entre otros.
#
# Limpieza de datos: Una vez que tenga los datos, es importante limpiarlos. Esto significa eliminar datos faltantes o erróneos, corregir errores de formato y estandarizar la información.
#
# Análisis exploratorio: El análisis exploratorio implica explorar los datos para comprender su distribución, la relación entre las variables y cualquier patrón o tendencia. Se pueden utilizar técnicas estadísticas y gráficas para visualizar y resumir los datos.
#
# Visualización de datos: La visualización de datos es una parte clave del EDA, ya que puede ayudar a identificar patrones y tendencias en los datos. Se pueden utilizar diferentes tipos de gráficos y visualizaciones, como histogramas, diagramas de dispersión y diagramas de caja y bigotes, entre otros.
#
# Modelado de datos: Finalmente, puede utilizar los datos limpios y analizados para construir modelos que puedan predecir resultados futuros. Estos modelos pueden basarse en técnicas estadísticas o de aprendizaje automático.

# %%
#Importamos las librerias a usar
import pandas as pd
from collections import Counter

# %%
df = pd.read_csv('dataset_plataformas.csv')

# %%
df
# Out:
#            id show_id     type  \
# 0         ds1      s1    movie
# 1         ds2      s2    movie
# 2         ds3      s3    movie
# 3         ds4      s4    movie
# 4         ds5      s5  tv show
# ...       ...     ...      ...
# 22993  ns8803   s8803    movie
# 22994  ns8804   s8804  tv show
# 22995  ns8805   s8805    movie
# 22996  ns8806   s8806    movie
# 22997  ns8807   s8807    movie
#
#                                                   title  \
# 0      duck the halls: a mickey mouse christmas special
# 1                                ernest saves christmas
# 2                          ice age: a mammoth christmas
# 3                            the queen family singalong
# 4                                 the beatles: get back
# ...                                                 ...
# 22993                                            zodiac
# 22994                                       zombie dumb
# 22995                                        zombieland
# 22996                                              zoom
# 22997                                            zubaan
#
#                                 director  \
# 0      alonso ramirez ramos, dave wasson
# 1                            john cherry
# 2                           karen disher
# 3                        hamish hamilton
# 4                                      0
# ...                                  ...
# 22993                      david fincher
# 22994                                  0
# 22995                    ruben fleischer
# 22996                       peter hewitt
# 22997                        mozez singh
#
#                                                     cast        country  \
# 0      chris diamantopoulos, tony anselmo, tress macn...              0
# 1               jim varney, noelle parker, douglas seale              0
# 2      raymond albert romano, john leguizamo, denis l...  united states
# 3      darren criss, adam lambert, derek hough, alexa...              0
# 4      john lennon, paul mccartney, george harrison, ...              0
# ...                                                  ...            ...
# 22993  mark ruffalo, jake gyllenhaal, robert downey j...  united states
# 22994                                                  0              0
# 22995  jesse eisenberg, woody harrelson, emma stone, ...  united states
# 22996  tim allen, courteney cox, chevy chase, kate ma...  united states
# 22997  vicky kaushal, sarah-jane dias, raaghav chanan...          india
#
#                 date_added  release_year rating_x  \
# 0      2021-11-26 00:00:00          2016     tv-g
# 1      2021-11-26 00:00:00          1988       pg
# 2      2021-11-26 00:00:00          2011     tv-g
# 3      2021-11-26 00:00:00          2021    tv-pg
# 4      2021-11-25 00:00:00          2021        g
# ...                    ...           ...      ...
# 22993  2019-11-20 00:00:00          2007        r
# 22994  2019-07-01 00:00:00          2018    tv-y7
# 22995  2019-11-01 00:00:00          2009        r
# 22996  2020-01-11 00:00:00          2006       pg
# 22997  2019-03-02 00:00:00          2015    tv-14
#
#                                             listed_in  \
# 0                                   animation, family
# 1                                              comedy
# 2                           animation, comedy, family
# 3                                             musical
# 4                       docuseries, historical, music
# ...                                               ...
# 22993                  cult movies, dramas, thrillers
# 22994          kids' tv, korean tv shows, tv comedies
# 22995                         comedies, horror movies
# 22996              children & family movies, comedies
# 22997  dramas, international movies, music & musicals
#
#                                              description  duration_int  \
# 0       join mickey and the gang as they duck the halls!            23
# 1      santa claus passes his magic bag to a new st. ...            91
# 2              sid the sloth is on santa's naughty list.            23
# 3                   this is real life, not just fantasy!            41
# 4      a three-part documentary from peter jackson ca...             1
# ...                                                  ...           ...
# 22993  a political cartoonist, a crime reporter and a...           158
# 22994  while living alone in a spooky town, a young g...             2
# 22995  looking to survive in a world taken over by zo...            88
# 22996  dragged from civilian life, a former superhero...            88
# 22997  a scrappy but poor boy worms his way into a ty...           111
#
#       duration_type  rating_y
# 0               min       3.6
# 1               min       3.5
# 2               min       3.6
# 3               min       3.5
# 4            season       3.5
# ...             ...       ...
# 22993           min       3.4
# 22994        season       3.5
# 22995           min       3.4
# 22996           min       3.6
# 22997           min       3.5
#
# [22998 rows x 15 columns]
